                  "AXAMTC001021", "AXAUNI000397", "AXAMTC001024", "AXAUNI000352", "AXAUNI000352", "AXAUNI000352",
                  "AXAMTC000046", "AXAMTC000046", "AXACLC000043", "AXAGRP000013", "AXAGRP000013", "AXAMTC000055",
                  "AXAMTC000055", "AXAMTC001026", "AXACLC000043", "AXAREC001027", "AXAREC001027", "AXAUNI001028",
                  "AXAMTC001029", "AXAREC000022", "AXAUNI001000", "AXAUNI001000", "AXAREC000022", "AXAREC000973",
                  "AXAREC000973", "AXAREC000991", "AXAREC000991", "AXAUNI000223", "AXAREC000058", "AXAREC001027"
                  ]

# %%
Legal_Gross = [-35, 0, 0, 0, 0, 35, 35, 0, 0, -28, 28, 35, 35, 35, 35, 35, 35, 35, 35, 35, 0, 0, 35, 35, 50, 35, 35, 35,
               35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, -35, 35, 0, 35, 35, 35, 35, 35, 35, 0, 28,
               35, 35, 35, 35, 35, 35, 0, 35, 35, 35, 35, 35, 35, 35, 35, 0, 35, 0, 35, 35, 28, 50, 35, 0, 35, 35, 35,
               0, 0, 0, -35, 35, -35, -35, 35, -35, 35, 35, 35, -35, 35, 35, 35, -35, -35, 35, 35, -35, 35, -35, 35, 0,
               2.4, 35
               ]

# %%
new_total_premiums = []
new_Commissions = []
new_policy_numbers = []
new_Legal_Gross = []

# %%
for policy_number, total_premium, Commission in zip(policy_numbers, total_premiums, Commissions):
    print(policy_number, str(total_premium).rjust(15), str(Commission).rjust(10))
# Out:
# AXAUNI000397        -2719.28    -815.77
# AXAREC000189        -1938.87    -387.77
# AXAREC000189         1938.87     387.77
# AXAUNI000224          413.16     123.95
# AXAUNI000224         -413.16    -123.95
# AXAUNI000030         2139.49     641.85
# AXAUNI000033         2214.67     664.41
# AXACLC000165          210.86      63.26
# AXACLC000165         -210.86     -63.26
# AXAREC000026       -11551.28        0.0
# AXAREC000026        11551.28        0.0
# AXAUNI000045         1472.93     441.88
# AXAUNI000001          786.86     236.05
# AXACLC000043          733.66      220.1
# AXAMTC001005          873.15     261.95
# AXAUNI000056         1698.76     509.62
# AXAUNI000068         4412.33     1323.7
# AXAMTP000008         2215.46     664.64
# AXAUNI000039         3217.37     965.22
# AXAUNI000044         1582.07     474.63
# AXAMTC000249             0.0        0.0
# AXAMTC000249             0.0        0.0
# AXAREC000032         1603.43     320.69
# ...

# %%
print("No.".ljust(5), "policy_number".ljust(20), "total_prem_exc".ljust(20), "total_comm".ljust(15), "main".ljust(35), 
      "LXI".ljust(25), "Legal_ gross", end="\n\n")
for i in range(len(new_policy_numbers)):
    main_value = [new_main[i][0], round(new_main[i][1], 2), round(new_main[i][2], 2)]
    print(str(i+1).ljust(5), new_policy_numbers[i].ljust(20), str(new_total_premiums[i]).ljust(20), str(new_Commissions[i]).ljust(15), 
          str(main_value).ljust(35), str(new_LXI[i]).ljust(25), str(new_Legal_Gross[i]))

print()
print("".ljust(5), "".ljust(20), str(sum(new_total_premiums)).ljust(20), str(sum(new_Commissions)).ljust(15), "".ljust(35), 
      "".ljust(25), str(sum(new_Legal_Gross)), end="\n\n")
# Out:
# No.   policy_number        total_prem_exc       total_comm      main                                LXI                       Legal_ gross
#
# 1     AXAREC000189         -1938.87             -387.77         ['7085396', -1938.87, -387.77]      ['7085396', 0.0, 0]       0
# 2     AXAREC000189         1938.87              387.77          ['7085396', 1938.87, 387.77]        ['7085396', 0.0, 0]       0
# 3     AXAREC000026         -11551.28            0.0             ['7085396', -11551.28, 0.0]         ['7085396', -28.0, 0]     -28
# 4     AXAREC000026         11551.28             0.0             ['7085396', 11551.28, 0.0]          ['7085396', 28.0, 0]      28
# 5     AXAREC000032         1603.43              320.69          ['7085396', 1603.43, 320.69]        ['7085396', 35.0, 0]      35
# 6     AXAREC000020         2764.12              552.82          ['7085396', 2764.12, 552.82]        ['7085396', 35.0, 0]      35
# ...

# %%
for idx, value in enumerate(zip(policy_numbers, total_premiums, Commissions, Legal_Gross)):
    if value[1] == 0 and value[2] == 0:
        continue
    else:
        if value[0].startswith("AXAREC"):
            new_policy_numbers.append(value[0])
            new_total_premiums.append(value[1])
            new_Commissions.append(value[2])
            new_Legal_Gross.append(value[3])

# %%
new_main = []
new_LXI = []

# %%
for item in Main[1:]:
    if item[0] != "":
        new_main.append(item)

# %%
for item in LXI[1:]:
    if item[0] != "":
        new_LXI.append(item)

# %%
new_LXI
# Out:
# [['7085396', 0.0, 0],
#  ['7085396', 0.0, 0],
#  ['7085396', -28.0, 0],
#  ['7085396', 28.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 28.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 28.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 0.0, 0],
#  ['7085396', -35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', -35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', -35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', -35.0, 0],
#  ['7085396', 35.0, 0],
#  ['7085396', 2.4, 0],
#  ['7085396', 35.0, 0]]

# %%
for idx, value in enumerate(zip(policy_numbers, Main)):
    if value[0].startswith("AXAREC"):
        print(value)
# Out:
# ('AXAREC000189', ['', -2719.28, -815.7676843199998])
# ('AXAREC000189', ['7085396', -1938.87, -387.76818339])
# ('AXAREC000026', ['', -210.86, -63.25989774000001])
# ('AXAREC000026', ['7085396', -11551.28, 0.0])
# ('AXAREC000032', ['', 3219.97, 965.98778003])
# ('AXAREC000020', ['', 2914.38, 874.3081712399999])
# ('AXAREC000041', ['', 750.0, 225.00975])
# ('AXAREC000040', ['7085396', 3970.35, 794.07])
# ('AXAREC000048', ['', 1728.7, 518.61])
# ('AXAREC000036', ['', 5512.59, 1653.777])
# ('AXAREC000067', ['', 1045.76, 313.72904576])
# ('AXAREC001008', ['', 676.98, 203.08993812])
# ('AXAREC001007', ['', 3089.23, 926.7782676899999])
# ('AXAREC000084', ['7085396', 4505.32, 586.1286160399999])
# ('AXAREC000069', ['', 2164.94, 649.47983506])
# ('AXAREC000026', ['', 2445.4, 733.62])
# ('AXAREC001012', ['', 4811.06, 1443.30837788])
# ('AXAREC000755', ['', -1591.8, -318.3600000000001])
# ('AXAREC001027', ['7085396', 735.0, 147.0])
# ('AXAREC001027', ['7085396', -1021.75, -306.529087])
# ...

# %%
# Out:
# 19
